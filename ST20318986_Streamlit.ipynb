# %% [markdown]
# <a href="https://colab.research.google.com/github/zukhrafarshadz-sudo/PDA/blob/main/ST20318986_Streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip aqi_streamlit_app.zip
# Out:
# Archive:  aqi_streamlit_app.zip
#    creating: aqi_streamlit_app/
#    creating: aqi_streamlit_app/data/
#   inflating: aqi_streamlit_app/data/merged_aqi.csv
#    creating: aqi_streamlit_app/models/
#   inflating: aqi_streamlit_app/models/feature_list.joblib
#   inflating: aqi_streamlit_app/models/rf_aqi_model.joblib
#    creating: aqi_streamlit_app/.ipynb_checkpoints/
#    creating: aqi_streamlit_app/pages/
#   inflating: aqi_streamlit_app/pages/Model_Explanation.py
#   inflating: aqi_streamlit_app/pages/2_EDA.py
#    creating: aqi_streamlit_app/pages/.ipynb_checkpoints/
#   inflating: aqi_streamlit_app/pages/1_Data_Overview.py
#   inflating: aqi_streamlit_app/pages/3_Modelling_&_Prediction.py
#    creating: aqi_streamlit_app/__pycache__/
#   inflating: aqi_streamlit_app/__pycache__/utils.cpython-312.pyc
#   inflating: aqi_streamlit_app/utils.py
#  extracting: aqi_streamlit_app/requirements.txt
#   inflating: aqi_streamlit_app/app.py

# %%
# !pip -q install streamlit pandas numpy scikit-learn joblib plotly
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 66.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 84.4 MB/s eta 0:00:00

# %%
# !pkill -f streamlit || true

# !nohup streamlit run /content/aqi_streamlit_app/app.py \
  --server.port 8501 \
  --server.address 0.0.0.0 \
  --server.headless true \
  > streamlit.log 2>&1 &
# Out:
# ^C

# %%
# !lsof -i :8501 || true
# !tail -n 20 streamlit.log
# Out:
# COMMAND    PID USER   FD   TYPE DEVICE SIZE/OFF NODE NAME
# streamlit 1938 root   13u  IPv4  67180      0t0  TCP *:8501 (LISTEN)
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   URL: http://0.0.0.0:8501

# %%
# %cd /content
# !rm -f cloudflared cloudflared.log

# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !./cloudflared --version
# Out:
# /content
# cloudflared version 2025.11.1 (built 2025-11-07-16:59 UTC)

# %%
# !nohup /content/cloudflared tunnel --url http://localhost:8501 > /content/cloudflared.log 2>&1 &

# %%
# !sleep 3
# !grep -o "https://[-a-zA-Z0-9]*\.trycloudflare\.com" -m 1 /content/cloudflared.log
# Out:
# https://lol-indicating-ids-cancelled.trycloudflare.com
