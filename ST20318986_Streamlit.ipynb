# %% [markdown]
# <a href="https://colab.research.google.com/github/zukhrafarshadz-sudo/PDA/blob/main/ST20318986_Streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip aqi_streamlit_app.zip
# Out:
# Archive:  aqi_streamlit_app.zip
#    creating: content/aqi_streamlit_app/
#  extracting: content/aqi_streamlit_app/requirements.txt
#   inflating: content/aqi_streamlit_app/app.py
#    creating: content/aqi_streamlit_app/__pycache__/
#   inflating: content/aqi_streamlit_app/__pycache__/utils.cpython-312.pyc
#   inflating: content/aqi_streamlit_app/utils.py
#    creating: content/aqi_streamlit_app/pages/
#   inflating: content/aqi_streamlit_app/pages/1_Data_Overview.py
#   inflating: content/aqi_streamlit_app/pages/2_EDA.py
#   inflating: content/aqi_streamlit_app/pages/Model_Explanation.py
#   inflating: content/aqi_streamlit_app/pages/3_Modelling_&_Prediction.py
#    creating: content/aqi_streamlit_app/pages/.ipynb_checkpoints/
#    creating: content/aqi_streamlit_app/data/
#   inflating: content/aqi_streamlit_app/data/merged_aqi.csv
#    creating: content/aqi_streamlit_app/models/
#   inflating: content/aqi_streamlit_app/models/feature_list.joblib
# ...

# %%
# !pip -q install streamlit pandas numpy scikit-learn joblib plotly
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 32.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 73.8 MB/s eta 0:00:00

# %%
# !ls -lah /content/content/aqi_streamlit_app/app.py
# Out:
# -rw-r--r-- 1 root root 2.1K Jan  6 07:22 /content/content/aqi_streamlit_app/app.py

# %%
# !pkill -f streamlit || true

# !nohup streamlit run /content/content/aqi_streamlit_app/app.py \
  --server.port 8501 \
  --server.address 0.0.0.0 \
  --server.headless true \
  > streamlit.log 2>&1 &
# Out:
# ^C

# %%
# !lsof -i :8501 || true
# !tail -n 20 streamlit.log

# %%
# %cd /content
# !rm -f cloudflared cloudflared.log

# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !./cloudflared --version
# Out:
# /content
# cloudflared version 2025.11.1 (built 2025-11-07-16:59 UTC)

# %%
# !nohup /content/cloudflared tunnel --url http://localhost:8501 > /content/cloudflared.log 2>&1 &

# %%
# !sleep 3
# !grep -o "https://[-a-zA-Z0-9]*\.trycloudflare\.com" -m 1 /content/cloudflared.log
# Out:
# https://colors-batteries-payments-weeks.trycloudflare.com

# %%
from google.colab import files
files.download("aqi_streamlit_app.zip")
